# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\used_car_prices.csv")
df
# Out:
#       web-scraper-order              Car Model Month/Year Average price  \
# 0          1680204632-1  Skoda Octavia A8 2022    2023-03   967,000 EGP
# 1          1680204632-2  Skoda Octavia A8 2022    2023-02   979,000 EGP
# 2          1680204632-3  Skoda Octavia A8 2022    2023-01   917,000 EGP
# 3          1680204632-4  Skoda Octavia A8 2022    2022-12   881,000 EGP
# 4          1680204632-5  Skoda Octavia A8 2022    2022-11   868,000 EGP
# ...                 ...                    ...        ...           ...
# 79085  1680204632-79086         Lada 2107 1991    2018-08    30,000 EGP
# 79086  1680204632-79087         Lada 2107 1991    2018-07    33,000 EGP
# 79087  1680204632-79088         Lada 2107 1991    2018-01    28,000 EGP
# 79088  1680204632-79089         Lada 2107 1991    2017-12    27,000 EGP
# 79089  1680204632-79090         Lada 2107 1991    2016-03    24,000 EGP
#
#       Minimum price  Maximum price
# 0       926,000 EGP  1,017,000 EGP
# 1       931,000 EGP  1,045,000 EGP
# 2       893,000 EGP    950,000 EGP
# 3       793,000 EGP    950,000 EGP
# 4       789,000 EGP    950,000 EGP
# ...             ...            ...
# 79085    26,000 EGP     33,000 EGP
# 79086    32,000 EGP     35,000 EGP
# 79087    25,000 EGP     30,000 EGP
# 79088    25,000 EGP     28,000 EGP
# 79089    23,000 EGP     26,000 EGP
#
# [79090 rows x 6 columns]

# %%
df.head(8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79090 entries, 0 to 79089
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   web-scraper-order  79090 non-null  object
#  1   Car Model          79090 non-null  object
#  2   Month/Year         78612 non-null  object
#  3   Average price      78612 non-null  object
#  4   Minimum price      78612 non-null  object
#  5   Maximum price      78612 non-null  object
# dtypes: object(6)
# memory usage: 3.6+ MB

# %%
df.shape
# Out:
# (79090, 6)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# web-scraper-order      0
# Car Model              0
# Month/Year           478
# Average price        478
# Minimum price        478
# Maximum price        478
# dtype: int64

# %%
df.columns = df.columns.str.title()
df
# Out:
#       Web-Scraper-Order              Car Model Month/Year Average Price  \
# 0          1680204632-1  Skoda Octavia A8 2022    2023-03   967,000 EGP
# 1          1680204632-2  Skoda Octavia A8 2022    2023-02   979,000 EGP
# 2          1680204632-3  Skoda Octavia A8 2022    2023-01   917,000 EGP
# 3          1680204632-4  Skoda Octavia A8 2022    2022-12   881,000 EGP
# 4          1680204632-5  Skoda Octavia A8 2022    2022-11   868,000 EGP
# ...                 ...                    ...        ...           ...
# 79085  1680204632-79086         Lada 2107 1991    2018-08    30,000 EGP
# 79086  1680204632-79087         Lada 2107 1991    2018-07    33,000 EGP
# 79087  1680204632-79088         Lada 2107 1991    2018-01    28,000 EGP
# 79088  1680204632-79089         Lada 2107 1991    2017-12    27,000 EGP
# 79089  1680204632-79090         Lada 2107 1991    2016-03    24,000 EGP
#
#       Minimum Price  Maximum Price
# 0       926,000 EGP  1,017,000 EGP
# 1       931,000 EGP  1,045,000 EGP
# 2       893,000 EGP    950,000 EGP
# 3       793,000 EGP    950,000 EGP
# 4       789,000 EGP    950,000 EGP
# ...             ...            ...
# 79085    26,000 EGP     33,000 EGP
# 79086    32,000 EGP     35,000 EGP
# 79087    25,000 EGP     30,000 EGP
# 79088    25,000 EGP     28,000 EGP
# 79089    23,000 EGP     26,000 EGP
#
# [79090 rows x 6 columns]

# %%
df[["Average Price","Minimum Price","Maximum Price"]].isnull().sum()
# Out:
# Average Price    0
# Minimum Price    0
# Maximum Price    0
# dtype: int64

# %%
df[["Year","Month"]] = df['Month/Year'].str.split("-",expand = True)
df
# Out:
#       Web-Scraper-Order              Car Model Month/Year Average Price  \
# 0          1680204632-1  Skoda Octavia A8 2022    2023-03   967,000 EGP
# 1          1680204632-2  Skoda Octavia A8 2022    2023-02   979,000 EGP
# 2          1680204632-3  Skoda Octavia A8 2022    2023-01   917,000 EGP
# 3          1680204632-4  Skoda Octavia A8 2022    2022-12   881,000 EGP
# 4          1680204632-5  Skoda Octavia A8 2022    2022-11   868,000 EGP
# ...                 ...                    ...        ...           ...
# 79085  1680204632-79086         Lada 2107 1991    2018-08    30,000 EGP
# 79086  1680204632-79087         Lada 2107 1991    2018-07    33,000 EGP
# 79087  1680204632-79088         Lada 2107 1991    2018-01    28,000 EGP
# 79088  1680204632-79089         Lada 2107 1991    2017-12    27,000 EGP
# 79089  1680204632-79090         Lada 2107 1991    2016-03    24,000 EGP
#
#       Minimum Price  Maximum Price  Year Month
# 0       926,000 EGP  1,017,000 EGP  2023    03
# 1       931,000 EGP  1,045,000 EGP  2023    02
# 2       893,000 EGP    950,000 EGP  2023    01
# 3       793,000 EGP    950,000 EGP  2022    12
# 4       789,000 EGP    950,000 EGP  2022    11
# ...             ...            ...   ...   ...
# 79085    26,000 EGP     33,000 EGP  2018    08
# 79086    32,000 EGP     35,000 EGP  2018    07
# 79087    25,000 EGP     30,000 EGP  2018    01
# 79088    25,000 EGP     28,000 EGP  2017    12
# 79089    23,000 EGP     26,000 EGP  2016    03
#
# [79090 rows x 8 columns]

# %%
df.drop("Month/Year", axis=1, inplace=True)
df
# Out:
#       Web-Scraper-Order              Car Model Average Price Minimum Price  \
# 0          1680204632-1  Skoda Octavia A8 2022   967,000 EGP   926,000 EGP
# 1          1680204632-2  Skoda Octavia A8 2022   979,000 EGP   931,000 EGP
# 2          1680204632-3  Skoda Octavia A8 2022   917,000 EGP   893,000 EGP
# 3          1680204632-4  Skoda Octavia A8 2022   881,000 EGP   793,000 EGP
# 4          1680204632-5  Skoda Octavia A8 2022   868,000 EGP   789,000 EGP
# ...                 ...                    ...           ...           ...
# 79085  1680204632-79086         Lada 2107 1991    30,000 EGP    26,000 EGP
# 79086  1680204632-79087         Lada 2107 1991    33,000 EGP    32,000 EGP
# 79087  1680204632-79088         Lada 2107 1991    28,000 EGP    25,000 EGP
# 79088  1680204632-79089         Lada 2107 1991    27,000 EGP    25,000 EGP
# 79089  1680204632-79090         Lada 2107 1991    24,000 EGP    23,000 EGP
#
#        Maximum Price  Year Month
# 0      1,017,000 EGP  2023    03
# 1      1,045,000 EGP  2023    02
# 2        950,000 EGP  2023    01
# 3        950,000 EGP  2022    12
# 4        950,000 EGP  2022    11
# ...              ...   ...   ...
# 79085     33,000 EGP  2018    08
# 79086     35,000 EGP  2018    07
# 79087     30,000 EGP  2018    01
# 79088     28,000 EGP  2017    12
# 79089     26,000 EGP  2016    03
#
# [79090 rows x 7 columns]

# %%
df['Average Price'] = pd.to_numeric(df['Average Price'], errors='coerce')
df['Minimum Price'] = pd.to_numeric(df['Minimum Price'], errors='coerce')
df['Maximum Price'] = pd.to_numeric(df['Maximum Price'], errors='coerce')
df
# Out:
#       Web-Scraper-Order              Car Model  Average Price  Minimum Price  \
# 0          1680204632-1  Skoda Octavia A8 2022            NaN            NaN
# 1          1680204632-2  Skoda Octavia A8 2022            NaN            NaN
# 2          1680204632-3  Skoda Octavia A8 2022            NaN            NaN
# 3          1680204632-4  Skoda Octavia A8 2022            NaN            NaN
# 4          1680204632-5  Skoda Octavia A8 2022            NaN            NaN
# ...                 ...                    ...            ...            ...
# 79085  1680204632-79086         Lada 2107 1991            NaN            NaN
# 79086  1680204632-79087         Lada 2107 1991            NaN            NaN
# 79087  1680204632-79088         Lada 2107 1991            NaN            NaN
# 79088  1680204632-79089         Lada 2107 1991            NaN            NaN
# 79089  1680204632-79090         Lada 2107 1991            NaN            NaN
#
#        Maximum Price  Year Month
# 0                NaN  2023    03
# 1                NaN  2023    02
# 2                NaN  2023    01
# 3                NaN  2022    12
# 4                NaN  2022    11
# ...              ...   ...   ...
# 79085            NaN  2018    08
# 79086            NaN  2018    07
# 79087            NaN  2018    01
# 79088            NaN  2017    12
# 79089            NaN  2016    03
#
# [79090 rows x 7 columns]

# %%
for column in ["Average Price","Minimum Price","Maximum Price"]:
        mean_value = df[column].mean
        median_value = df[column].median
        mode_value = df[column].mode

        df[column].fillna(mean_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# Web-Scraper-Order      0
# Car Model              0
# Average Price          0
# Minimum Price          0
# Maximum Price          0
# Year                 478
# Month                478
# dtype: int64
